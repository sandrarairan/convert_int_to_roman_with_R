# %% [markdown]
# # DOCUMENTACION APP CONVERTIR UN ENTERO A ROMANO

# %% [markdown]
# - La biblioteca **utils** trae un diccionario con los valores y letras de los
# números romans recomendado utilizar **.romans**

# %%
La imagen de la aplicación en Shiny

# %%
from IPython import display 
display.Image("/Users/sandrarairan/Documents/practica_shiny/convert_int_to_roman/appromam.jpg")

# %% [markdown]
# ## El app funciona de la siguiente forma:
#
# * Ingresar un número entero en el campo de text
#
# * Mover el slider
#
# * Click en el botón convertir y se despliega la conversión en la parte derecha.
